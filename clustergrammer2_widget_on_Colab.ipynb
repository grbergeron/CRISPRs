# %% [markdown]
# <a href="https://colab.research.google.com/github/grbergeron/CRISPRs/blob/master/clustergrammer2_widget_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clustergrammer2 Widget on Coab

# %%
# enable custom widgets 
# https://github.com/googlecolab/colabtools/issues/498
from google.colab import output
output.enable_custom_widget_manager()

# %%
# %%capture

# !pip install clustergrammer2
from clustergrammer2 import net
import numpy as np
import pandas as pd

from IPython.display import Javascript
def resize_colab_cell():
  display(Javascript('google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'))
get_ipython().events.register('pre_run_cell', resize_colab_cell)

# %%
# generate random matrix
num_cols = 100
num_rows = 100

np.random.seed(seed=100)
mat = np.random.rand(num_rows, num_cols)

# make row and col labels
rows = range(num_rows)
cols = range(num_cols)
rows = [str(i) for i in rows]
cols = [str(i) for i in cols]

# make dataframe 
df = pd.DataFrame(data=mat, columns=cols, index=rows)
df.shape
# Out:
# (100, 100)

# %%
df_meta = pd.DataFrame('Undefined', index=df.columns.tolist(), columns=['Label'])

# %%
# setting some preferred categories is required, but you can write out other 
# custom categories as well in the dendrogram menu
meta_cat = pd.DataFrame()
meta_cat.loc['dog', 'color'] = 'red'
meta_cat.loc['cat', 'color'] = 'blue'

# %%
net.load_df(df, meta_col=df_meta)
net.set_manual_category(col='Label', preferred_cats=meta_cat)
net.widget()
# Out:
# CGM2(manual_cat='{"col": {"col_cat_colors": {"Label: Undefined": "#393b79"}, "Label": {"0": "Undefined", "1": …

# %%
df_meta['Label'].value_counts()
# Out:
# Undefined    100
# Name: Label, dtype: int64
